# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
from platform import python_version
print(python_version())
# Out:
# TensorFlow 1.x selected.
# 1.15.2
# 3.7.10

# %%
# %cd /content/drive/MyDrive/Classwork/CSE_257/DREAM/
# Out:
# /content/drive/MyDrive/Classwork/CSE_257/DREAM

# %%
# !python controller_device.py
# Out:
# WARNING:tensorflow:From controller_device.py:637: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From controller_device.py:639: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/utils.py:168: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   feats = np.vstack(_ for _ in all_feats)
# processing graph 0 id 0
# processing graph 1 id 1
# processing graph 2 id 2
# processing graph 3 id 3
# processing graph 4 id 4
# processing graph 5 id 5
# processing graph 6 id 6
# processing graph 7 id 7
# processing graph 8 id 8
# processing graph 9 id 9
# processing graph 10 id 10
# processing graph 11 id 11
# processing graph 12 id 12
# processing graph 13 id 13
# processing graph 14 id 14
# processing graph 15 id 15
# processing graph 16 id 16
# processing graph 17 id 17
# processing graph 18 id 18
# processing graph 19 id 19
# processing graph 20 id 20
# processing graph 21 id 21
# processing graph 22 id 22
# processing graph 23 id 23
# processing graph 24 id 24
# processing graph 25 id 25
# processing graph 26 id 26
# processing graph 27 id 27
# processing graph 28 id 28
# processing graph 29 id 29
# processing graph 30 id 30
# processing graph 31 id 31
# processing graph 32 id 32
# processing graph 33 id 33
# processing graph 34 id 34
# processing graph 35 id 35
# processing graph 36 id 36
# processing graph 37 id 37
# processing graph 38 id 38
# processing graph 39 id 39
# processing graph 40 id 40
# processing graph 41 id 41
# processing graph 42 id 42
# processing graph 43 id 43
# processing graph 44 id 44
# processing graph 45 id 45
# processing graph 46 id 46
# processing graph 47 id 47
# processing graph 48 id 48
# processing graph 49 id 49
# [27, 35, 40, 38, 2, 3, 48, 29, 46, 31, 32, 39, 21, 36, 19, 42, 49, 26, 22, 13, 41, 17, 45, 24, 23, 4, 33, 14, 30, 10, 28, 44, 34, 18, 20, 25, 6, 7, 47, 1]
# (50, 5, 2)
# [2, 128, 128]
# WARNING:tensorflow:From /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/layers.py:93: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/layers.py:94: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/inits.py:18: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# max pooling dimension 2 and 128, True
# max pooling dimension 256 and 128, True
# max pooling graph dimension 512 and 512
# WARNING:tensorflow:From /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/neigh_samplers.py:34: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Classwork/CSE_257/DREAM/graphsage/layers.py:107: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From controller_device.py:211: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From controller_device.py:1108: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From controller_device.py:1109: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From controller_device.py:740: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From controller_device.py:757: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From controller_device.py:757: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From controller_device.py:1266: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From controller_device.py:1275: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From controller_device.py:1279: The name tf.global_norm is deprecated. Please use tf.linalg.global_norm instead.
#
# WARNING:tensorflow:From controller_device.py:247: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-05-25 18:34:41.507778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-25 18:34:41.576072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:41.576691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-05-25 18:34:41.602350: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 18:34:41.791382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-25 18:34:41.913552: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-25 18:34:41.931504: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-25 18:34:42.114185: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-25 18:34:42.142325: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-25 18:34:42.498610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 18:34:42.498812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.499525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.500053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-25 18:34:42.500545: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2021-05-25 18:34:42.517158: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000170000 Hz
# 2021-05-25 18:34:42.517458: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x565028a29100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 18:34:42.517499: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-05-25 18:34:42.632742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.633555: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x565028a292c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-05-25 18:34:42.633587: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-05-25 18:34:42.633776: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.634336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-05-25 18:34:42.634422: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 18:34:42.634448: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-05-25 18:34:42.634482: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-05-25 18:34:42.634505: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-05-25 18:34:42.634526: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-05-25 18:34:42.634549: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-05-25 18:34:42.634572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-05-25 18:34:42.634651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.635213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.635729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-05-25 18:34:42.638848: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-05-25 18:34:42.640157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-05-25 18:34:42.640186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-05-25 18:34:42.640197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-05-25 18:34:42.641290: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.641932: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-25 18:34:42.642476: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-05-25 18:34:42.642521: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From controller_device.py:253: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From controller_device.py:254: The name tf.local_variables_initializer is deprecated. Please use tf.compat.v1.local_variables_initializer instead.
#
# WARNING:tensorflow:From controller_device.py:255: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# start epoch 0 1621967686.3598206
# 2021-05-25 18:35:22.317862: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# Model saved in path: checkpoints/mode.0.ckpt
# start epoch 1 1621967724.882588
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 2 1621967764.8271117
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 3 1621967805.530254
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 4 1621967846.4266658
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 5 1621967887.6587875
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 6 1621967928.9992764
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 7 1621967970.27852
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 8 1621968011.58752
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 9 1621968053.196718
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 10 1621968094.506407
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# Model saved in path: checkpoints/mode.10.ckpt
# start epoch 11 1621968136.1647706
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 12 1621968177.711416
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 13 1621968219.036103
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 14 1621968260.2905865
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 15 1621968301.8931024
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 16 1621968343.4214234
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 17 1621968384.7816148
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 18 1621968426.1471655
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 19 1621968467.548235
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# start epoch 20 1621968508.8233595
# evaluating graph 0, greedy placement
# action 0111 rank 0.0
# evaluating graph 5, greedy placement
# action 0111 rank 0.0
# evaluating graph 8, greedy placement
# action 0011 rank 0.0
# evaluating graph 9, greedy placement
# action 0111 rank 0.0
# evaluating graph 11, greedy placement
# action 0011 rank 0.0
# evaluating graph 12, greedy placement
# action 0111 rank 0.0
# evaluating graph 15, greedy placement
# action 0011 rank 0.0
# evaluating graph 16, greedy placement
# action 0011 rank 0.0
# evaluating graph 37, greedy placement
# action 0011 rank 0.0
# evaluating graph 43, greedy placement
# action 0111 rank 0.0
# Model saved in path: checkpoints/mode.20.ckpt

# %%
import pandas as pd
# %cd checkpoints
# Out:
# /content/drive/My Drive/Classwork/CSE_257/DREAM/checkpoints

# %%
df = pd.read_pickle('20.pkl')

# %%
dir(df[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'best_rank',
#  'calculate_baseline',
#  'exploration_buf',
#  'exploration_done',
#  'graph_idx',
#  'hard_problem',
#  'has',
#  'if_exist',
#  'max_throughput',
#  'min_throughput',
#  'num_policy_samples',
#  'perf_map',
#  'policy_queue',
#  'policy_queue_length',
#  'replay',
#  'replay_buffer',
#  'sample',
#  'save',
#  'save_test',
#  'set_exploration_done']

# %%
df[16].perf_map
# Out:
# {'0011': 0.0}
